# %%
import pandas as pd

# %%
df = pd.read_csv("Spotify_rock_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 37

# %%
df = pd.read_csv("Spotify_pop_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 21

# %%
df = pd.read_csv("Spotify_chill_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 20

# %%
df = pd.read_csv("Spotify_latin_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 20

# %%
df = pd.read_csv("Spotify_rock_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 103

# %%
df = pd.read_csv("Spotify_pop_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 96

# %%
df = pd.read_csv("Spotify_chill_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 58

# %%
df = pd.read_csv("Spotify_latin_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 173
