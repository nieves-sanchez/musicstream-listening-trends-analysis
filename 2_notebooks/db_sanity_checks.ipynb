# %% [markdown]
# ✅ En este notebook se aplican comprobaciones de coherencia (sanity checks) a los conjuntos de datos en formato CSV, verificando la longitud y consistencia de algunas columnas con el objetivo de prevenir problemas al cargar la información en la base de datos.

# %%
import pandas as pd

# %%
df = pd.read_csv("../3_data/processed/final/tracks_rock_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 37

# %%
df = pd.read_csv("../3_data/processed/final/tracks_pop_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 21

# %%
df = pd.read_csv("../3_data/processed/final/tracks_chill_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 20

# %%
df = pd.read_csv("../3_data/processed/final/tracks_latin_final.csv")

df["artist_name_raw"].str.len()

max_caracteres = df["artist_name_raw"].str.len().max()
print(max_caracteres)
# Out:
# 20

# %%
df = pd.read_csv("../3_data/processed/final/tracks_rock_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 103

# %%
df = pd.read_csv("../3_data/processed/final/tracks_pop_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 96

# %%
df = pd.read_csv("../3_data/processed/final/tracks_chill_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 58

# %%
df = pd.read_csv("../3_data/processed/final/tracks_latin_final.csv")

df["name_track"].str.len()

max_caracteres = df["name_track"].str.len().max()
print(max_caracteres)
# Out:
# 173
